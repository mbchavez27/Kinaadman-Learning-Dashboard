# %%
import numpy as np
import pandas as pd 

subjectRecommendation = {
    "Physical Education and Health 4": ["Physical Education for Lifelong Fitness",
    "Teaching Children Physical Education: Becoming a Master Teacher",
    "Introduction to Kinesiology: Studying Physical Activity"],
      "Immersion/Internship (Applied)": [
         "The Internship Bible",
     "Intern Talk: The Ultimate Guide to Landing and Succeeding in an Internship",
    "All Work, No Pay: Finding an Internship, Building Your Resume, Making Connections, and Gaining Job Experience"
    ],
    "Disaster Readiness and Risk Reduction": [
          "Disaster Readiness: A Practical Guide for Preparing Your Home and Community",
    "Risk Reduction and Disaster Preparedness: An Introduction",
    "Disaster Risk Reduction: Cases from Urban Africa"
    ],
    "Introduction to the Philosophy of the Human Person": [
        "Philosophy of the Human Person: An Introductory Anthology",
    "Being Human: An Introduction to the Philosophy of the Human Person",
    "Human Person: An Introduction to Philosophy"
    ],
    "Filipino sa Larangan ng Akademik": [
           "Akademikong Filipino: Wika't Pagbasa sa Iba't Ibang Disiplina",
    "Filipino sa Larangan ng Akademik: Isang Gabay sa Pagsulat at Pananaliksik",
    "Sining ng Pakikipagtalastasan: Filipino sa Akademikong Larangan"
    ],
    "English for Academic and Professional Purposes": [
   "English for Academic Purposes: A Handbook for Students",
    "English for Professional Purposes: A Guide to Business and Professional Communication",
    "Academic Writing for Graduate Students: Essential Tasks and Skills"
    ]
    }

subjects = pd.DataFrame(subjectRecommendation)
subjects.to_csv("subjectRecommendation.csv")
subjects
# Out:
#                      Physical Education and Health 4
# 0            Physical Education for Lifelong Fitness  \
# 1  Teaching Children Physical Education: Becoming...
# 2  Introduction to Kinesiology: Studying Physical...
#
#                       Immersion/Internship (Applied)
# 0                               The Internship Bible  \
# 1  Intern Talk: The Ultimate Guide to Landing and...
# 2  All Work, No Pay: Finding an Internship, Build...
#
#                Disaster Readiness and Risk Reduction
# 0  Disaster Readiness: A Practical Guide for Prep...  \
# 1  Risk Reduction and Disaster Preparedness: An I...
# 2   Disaster Risk Reduction: Cases from Urban Africa
#
#   Introduction to the Philosophy of the Human Person
# 0  Philosophy of the Human Person: An Introductor...  \
# 1  Being Human: An Introduction to the Philosophy...
# 2        Human Person: An Introduction to Philosophy
#
#                     Filipino sa Larangan ng Akademik
# ...
